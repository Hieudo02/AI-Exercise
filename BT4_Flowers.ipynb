# %% [markdown]
# <a href="https://colab.research.google.com/github/Hieudo02/AI-Exercise/blob/main/BT4_Flowers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from os import listdir
from numpy import asarray, save
from keras.utils import load_img
from keras.utils import img_to_array

# %%
folder = '/content/drive/MyDrive/Colab Notebooks/BAITAP/FLOWER/'
photos, labels = list(), list()
for file in listdir(folder):
  output= 0.0
  if file.startswith('ROSE'):
    output= 1.0
  if file.startswith('DANDELION'):
    output= 2.0
  if file.startswith('DAISY'):
    output= 3.0
  if file.startswith('TULIP'):
    output= 4.0
  if file.startswith('SUNFLOWER'):
    output= 5.0
  photo = load_img(folder + file, target_size= (40,40))
  photo= img_to_array(photo)

  photos.append(photo)
  labels.append(output)

# %%
photos= asarray(photos)
labels= asarray(labels)
print(photos.shape, labels.shape)
save('/content/drive/MyDrive/Colab Notebooks/BAITAP/npyData/flower_photos.npy', photos)
save('/content/drive/MyDrive/Colab Notebooks/BAITAP/npyData/flower_labels.npy', labels)
# Out:
# (3952, 40, 40, 3) (3952,)

# %%
# Split data into train & test
split_index = int(0.05 * len(photos))
test_x, test_y = photos[:split_index], labels[:split_index]
train_x, train_y = photos[split_index:], labels[split_index:]

# %%
print(test_x.shape, train_x.shape)
# Out:
# (197, 40, 40, 3) (3755, 40, 40, 3)

# %%
train_x = train_x.reshape((3755, 40, 40, 3))
train_x = train_x.astype('float32')/255

test_x = test_x.reshape((197, 40, 40, 3))
test_x = test_x.astype('float32')/255

# %%
from keras.utils import to_categorical
train_y = to_categorical(train_y,6)
test_y = to_categorical(test_y,6)

# %%
from keras.models import Sequential,Model
from keras.layers import Dense,Flatten,Dropout,Conv2D,MaxPooling2D,Normalization,Input
from keras.optimizers import Adam
from keras import losses
loss = losses
batch_size = 64
epochs = 40
classes = 6

# %%
from keras.layers import LeakyReLU
model = Sequential()
model.add(Conv2D(32, kernel_size = (3,3), activation = 'linear', input_shape = (40, 40, 3), padding= 'same'))
model.add(LeakyReLU(alpha = 0.1))

model.add(MaxPooling2D((2,2), padding = 'same'))
model.add(Conv2D(64, (3,3), activation = 'linear', padding = 'same'))
model.add(Conv2D(64, (3,3), activation = 'linear', padding = 'same'))
model.add(LeakyReLU(alpha = 0.1))

model.add(MaxPooling2D((2,2), padding = 'same'))
model.add(Conv2D(128, (3,3), activation = 'linear', padding = 'same'))
model.add(LeakyReLU(alpha = 0.1))

model.add(MaxPooling2D((2,2), padding = 'same'))
model.add(Conv2D(256, (3,3), activation = 'linear', padding = 'same'))
model.add(LeakyReLU(alpha = 0.1))

model.add(MaxPooling2D((2,2), padding = 'same'))
model.add(Conv2D(512, (3,3), activation = 'linear', padding = 'same'))
model.add(LeakyReLU(alpha = 0.1))

model.add(MaxPooling2D((2,2), padding = 'same'))
model.add(Conv2D(1024, (3,3), activation = 'linear', padding = 'same'))
model.add(LeakyReLU(alpha = 0.1))

# %%
#Đưa vào ANN, bộ ANN để phân loại:
from keras.losses import categorical_crossentropy
model.add(Flatten())
model.add(Dense(1024, activation = 'linear'))

model.add(Dense(classes, activation = 'softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 40, 40, 32)        896
#
#  leaky_re_lu (LeakyReLU)     (None, 40, 40, 32)        0
#
#  max_pooling2d (MaxPooling2D  (None, 20, 20, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 20, 20, 64)        18496
#
#  conv2d_2 (Conv2D)           (None, 20, 20, 64)        36928
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 20, 20, 64)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 10, 10, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 10, 10, 128)       73856
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 10, 10, 128)       0
#
#  max_pooling2d_2 (MaxPooling  (None, 5, 5, 128)        0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 5, 5, 256)         295168
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 5, 5, 256)         0
#
#  max_pooling2d_3 (MaxPooling  (None, 3, 3, 256)        0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 3, 3, 512)         1180160
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 3, 3, 512)         0
#
#  max_pooling2d_4 (MaxPooling  (None, 2, 2, 512)        0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 2, 2, 1024)        4719616
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 2, 2, 1024)        0
#
#  flatten (Flatten)           (None, 4096)              0
#
#  dense (Dense)               (None, 1024)              4195328
#
#  dense_1 (Dense)             (None, 6)                 6150
#
# =================================================================
# Total params: 10,526,598
# Trainable params: 10,526,598
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Compile:
model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])
train = model.fit(train_x, train_y, batch_size= batch_size, epochs= epochs, verbose= 1)
# Out:
# Epoch 1/40
# 59/59 [==============================] - 15s 31ms/step - loss: 1.4966 - accuracy: 0.3680
# Epoch 2/40
# 59/59 [==============================] - 1s 19ms/step - loss: 1.1240 - accuracy: 0.5190
# Epoch 3/40
# 59/59 [==============================] - 1s 19ms/step - loss: 1.0021 - accuracy: 0.6029
# Epoch 4/40
# 59/59 [==============================] - 1s 18ms/step - loss: 0.8977 - accuracy: 0.6375
# Epoch 5/40
# 59/59 [==============================] - 1s 17ms/step - loss: 0.7777 - accuracy: 0.6881
# Epoch 6/40
# 59/59 [==============================] - 1s 17ms/step - loss: 0.7174 - accuracy: 0.7177
# Epoch 7/40
# 59/59 [==============================] - 1s 17ms/step - loss: 0.5862 - accuracy: 0.7654
# Epoch 8/40
# 59/59 [==============================] - 1s 17ms/step - loss: 0.4500 - accuracy: 0.8304
# Epoch 9/40
# 59/59 [==============================] - 1s 18ms/step - loss: 0.3487 - accuracy: 0.8751
# Epoch 10/40
# 59/59 [==============================] - 1s 18ms/step - loss: 0.3606 - accuracy: 0.8679
# Epoch 11/40
# 59/59 [==============================] - 1s 17ms/step - loss: 0.2552 - accuracy: 0.9116
# Epoch 12/40
# 59/59 [==============================] - 1s 17ms/step - loss: 0.1601 - accuracy: 0.9459
# Epoch 13/40
# 59/59 [==============================] - 1s 18ms/step - loss: 0.1780 - accuracy: 0.9422
# Epoch 14/40
# 59/59 [==============================] - 1s 19ms/step - loss: 0.0897 - accuracy: 0.9731
# Epoch 15/40
# 59/59 [==============================] - 1s 19ms/step - loss: 0.1096 - accuracy: 0.9643
# Epoch 16/40
# 59/59 [==============================] - 1s 19ms/step - loss: 0.1005 - accuracy: 0.9659
# Epoch 17/40
# 59/59 [==============================] - 1s 18ms/step - loss: 0.0734 - accuracy: 0.9747
# Epoch 18/40
# 59/59 [==============================] - 1s 18ms/step - loss: 0.0699 - accuracy: 0.9771
# Epoch 19/40
# 59/59 [==============================] - 1s 18ms/step - loss: 0.0882 - accuracy: 0.9696
# Epoch 20/40
# 59/59 [==============================] - 1s 18ms/step - loss: 0.0785 - accuracy: 0.9747
# Epoch 21/40
# 59/59 [==============================] - 1s 17ms/step - loss: 0.0433 - accuracy: 0.9854
# Epoch 22/40
# 59/59 [==============================] - 1s 18ms/step - loss: 0.0550 - accuracy: 0.9808
# Epoch 23/40
# 59/59 [==============================] - 1s 17ms/step - loss: 0.0441 - accuracy: 0.9851
# Epoch 24/40
# 59/59 [==============================] - 1s 17ms/step - loss: 0.0645 - accuracy: 0.9779
# Epoch 25/40
# 59/59 [==============================] - 1s 18ms/step - loss: 0.0977 - accuracy: 0.9694
# Epoch 26/40
# 59/59 [==============================] - 1s 18ms/step - loss: 0.0749 - accuracy: 0.9779
# Epoch 27/40
# 59/59 [==============================] - 1s 19ms/step - loss: 0.0342 - accuracy: 0.9888
# Epoch 28/40
# 59/59 [==============================] - 1s 19ms/step - loss: 0.0412 - accuracy: 0.9856
# Epoch 29/40
# 59/59 [==============================] - 1s 18ms/step - loss: 0.0592 - accuracy: 0.9808
# Epoch 30/40
# 59/59 [==============================] - 1s 18ms/step - loss: 0.0290 - accuracy: 0.9888
# Epoch 31/40
# 59/59 [==============================] - 1s 18ms/step - loss: 0.0243 - accuracy: 0.9928
# Epoch 32/40
# 59/59 [==============================] - 1s 18ms/step - loss: 0.0359 - accuracy: 0.9883
# Epoch 33/40
# 59/59 [==============================] - 1s 18ms/step - loss: 0.0451 - accuracy: 0.9870
# Epoch 34/40
# 59/59 [==============================] - 1s 18ms/step - loss: 0.0147 - accuracy: 0.9947
# Epoch 35/40
# 59/59 [==============================] - 1s 18ms/step - loss: 0.0868 - accuracy: 0.9731
# Epoch 36/40
# 59/59 [==============================] - 1s 18ms/step - loss: 0.1369 - accuracy: 0.9606
# Epoch 37/40
# 59/59 [==============================] - 1s 18ms/step - loss: 0.1156 - accuracy: 0.9601
# Epoch 38/40
# 59/59 [==============================] - 1s 25ms/step - loss: 0.0325 - accuracy: 0.9893
# Epoch 39/40
# 59/59 [==============================] - 1s 25ms/step - loss: 0.0244 - accuracy: 0.9920
# Epoch 40/40
# 59/59 [==============================] - 2s 28ms/step - loss: 0.0139 - accuracy: 0.9941

# %%
# Evaluate model
test_loss, test_acc = model.evaluate(test_x, test_y)
print('Test accuracy:', test_acc)
# Out:
# 7/7 [==============================] - 1s 39ms/step - loss: 1.8046 - accuracy: 0.7411
# Test accuracy: 0.7411167621612549

# %%
model.save('/content/drive/MyDrive/Colab Notebooks/BAITAP/modelFlowers.h5')

# %%
import matplotlib.pyplot as plt
import numpy as np
from os import listdir
from keras.utils import load_img
from keras.utils.image_utils import img_to_array
folder = '/content/drive/MyDrive/Colab Notebooks/BAITAP/load_Image/FLowers/'
for file in listdir(folder):
  photo = load_img(folder  +  file)
  plt.imshow(photo)
  
  photo = load_img(folder +   file, target_size = (40, 40))
  photo=img_to_array(photo)
  photo=photo.astype('float32')
  photo=photo/255
  photo=np.expand_dims(photo,axis=0)
  result=(model.predict(photo).argmax())
  class_name=['','ROSE', 'DANDELION', 'DAISY', 'TULIP', 'SUNFLOWER']
  print(class_name[result])
  plt.show()
# Out:
# 1/1 [==============================] - 0s 26ms/step
# DAISY
# 1/1 [==============================] - 0s 17ms/step
# TULIP
# 1/1 [==============================] - 0s 22ms/step
# DANDELION
# 1/1 [==============================] - 0s 19ms/step
# TULIP
# 1/1 [==============================] - 0s 28ms/step
# SUNFLOWER
